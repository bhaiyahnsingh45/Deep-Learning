# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('D:\\Data_sets\\Churn_Modelling.csv')
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
df = df.iloc[:,3:]

# %%
df
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0             1               1        101348.88       1
# 1             0               1        112542.58       0
# 2             1               0        113931.57       1
# 3             0               0         93826.63       0
# 4             1               1         79084.10       0
# ...         ...             ...              ...     ...
# 9995          1               0         96270.64       0
# 9996          1               1        101699.77       0
# 9997          0               1         42085.58       1
# 9998          1               0         92888.52       1
# 9999          1               0         38190.78       0
#
# [10000 rows x 11 columns]

# %%
X= df.iloc[:,:-1]

# %%
y=df.iloc[:,-1:]

# %%
geography = pd.get_dummies(X['Geography'], drop_first=True)

# %%
gender = pd.get_dummies(X['Gender'], drop_first=True)

# %%
geography
# Out:
#       Germany  Spain
# 0           0      0
# 1           0      1
# 2           0      0
# 3           0      0
# 4           0      1
# ...       ...    ...
# 9995        0      0
# 9996        0      0
# 9997        0      0
# 9998        1      0
# 9999        0      0
#
# [10000 rows x 2 columns]

# %%
X= pd.concat([X,geography,gender], axis=1)

# %%
X
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Germany  Spain  Male
# 0             1               1        101348.88        0      0     0
# 1             0               1        112542.58        0      1     0
# 2             1               0        113931.57        0      0     0
# 3             0               0         93826.63        0      0     0
# 4             1               1         79084.10        0      1     0
# ...         ...             ...              ...      ...    ...   ...
# 9995          1               0         96270.64        0      0     1
# 9996          1               1        101699.77        0      0     1
# 9997          0               1         42085.58        0      0     0
# 9998          1               0         92888.52        1      0     1
# 9999          1               0         38190.78        0      0     0
#
# [10000 rows x 13 columns]

# %%
X.drop(['Geography','Gender'],axis=1, inplace=True)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout

# %%
classifier = Sequential()

# %%
# Adding the input layer and the first hidden layer

# he_uniform and he_normal work weel with relu


classifier.add(Dense(units = 6, kernel_initializer = 'he_uniform',activation='relu',input_dim = 11))

# Adding the second hidden layer
classifier.add(Dense(units = 6, kernel_initializer = 'he_uniform',activation='relu'))

# Adding the output layer
classifier.add(Dense(units = 1, kernel_initializer = 'glorot_uniform', activation = 'sigmoid'))

# %%
classifier.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 6)                 72
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 42
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 121
# Trainable params: 121
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the ANN
classifier.compile(optimizer = 'Adamax', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# Fitting the ANN to the Training set
model_history=classifier.fit(X_train, y_train,validation_split=0.33, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.5832 - accuracy: 0.7753 - val_loss: 0.5549 - val_accuracy: 0.7933
# Epoch 2/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.5235 - accuracy: 0.7990 - val_loss: 0.5313 - val_accuracy: 0.7933
# Epoch 3/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.5035 - accuracy: 0.7990 - val_loss: 0.5167 - val_accuracy: 0.7933
# Epoch 4/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4906 - accuracy: 0.7990 - val_loss: 0.5066 - val_accuracy: 0.7933
# Epoch 5/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4813 - accuracy: 0.7990 - val_loss: 0.4983 - val_accuracy: 0.7933
# Epoch 6/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4736 - accuracy: 0.7990 - val_loss: 0.4917 - val_accuracy: 0.7933
# Epoch 7/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4675 - accuracy: 0.7990 - val_loss: 0.4864 - val_accuracy: 0.7933
# Epoch 8/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4623 - accuracy: 0.7990 - val_loss: 0.4815 - val_accuracy: 0.7933
# Epoch 9/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4579 - accuracy: 0.7990 - val_loss: 0.4774 - val_accuracy: 0.7933
# Epoch 10/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4538 - accuracy: 0.7990 - val_loss: 0.4735 - val_accuracy: 0.7933
# Epoch 11/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4499 - accuracy: 0.7990 - val_loss: 0.4697 - val_accuracy: 0.7933
# Epoch 12/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4466 - accuracy: 0.7990 - val_loss: 0.4665 - val_accuracy: 0.7933
# Epoch 13/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4435 - accuracy: 0.7990 - val_loss: 0.4634 - val_accuracy: 0.7933
# Epoch 14/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4409 - accuracy: 0.7990 - val_loss: 0.4608 - val_accuracy: 0.7933
# Epoch 15/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.4384 - accuracy: 0.7990 - val_loss: 0.4585 - val_accuracy: 0.7933
# Epoch 16/100
# 536/536 [==============================] - 2s 5ms/step - loss: 0.4363 - accuracy: 0.7990 - val_loss: 0.4567 - val_accuracy: 0.7933
# Epoch 17/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.4348 - accuracy: 0.7990 - val_loss: 0.4551 - val_accuracy: 0.7933
# Epoch 18/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4335 - accuracy: 0.7990 - val_loss: 0.4537 - val_accuracy: 0.7933
# Epoch 19/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4323 - accuracy: 0.7990 - val_loss: 0.4524 - val_accuracy: 0.7933
# Epoch 20/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4313 - accuracy: 0.7990 - val_loss: 0.4512 - val_accuracy: 0.7933
# Epoch 21/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4303 - accuracy: 0.7990 - val_loss: 0.4501 - val_accuracy: 0.7933
# Epoch 22/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.4294 - accuracy: 0.7990 - val_loss: 0.4493 - val_accuracy: 0.7933
# Epoch 23/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.4286 - accuracy: 0.7990 - val_loss: 0.4484 - val_accuracy: 0.7933
# Epoch 24/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.4279 - accuracy: 0.7990 - val_loss: 0.4475 - val_accuracy: 0.7933
# Epoch 25/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.4273 - accuracy: 0.7990 - val_loss: 0.4469 - val_accuracy: 0.7933
# Epoch 26/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.4265 - accuracy: 0.7990 - val_loss: 0.4462 - val_accuracy: 0.7933
# Epoch 27/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.4258 - accuracy: 0.7990 - val_loss: 0.4455 - val_accuracy: 0.7933
# Epoch 28/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.4250 - accuracy: 0.7990 - val_loss: 0.4445 - val_accuracy: 0.7933
# Epoch 29/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.4243 - accuracy: 0.7990 - val_loss: 0.4440 - val_accuracy: 0.7933
# Epoch 30/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4235 - accuracy: 0.7990 - val_loss: 0.4430 - val_accuracy: 0.7933
# Epoch 31/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4227 - accuracy: 0.7990 - val_loss: 0.4425 - val_accuracy: 0.7933
# Epoch 32/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4219 - accuracy: 0.7990 - val_loss: 0.4418 - val_accuracy: 0.7933
# Epoch 33/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4212 - accuracy: 0.7990 - val_loss: 0.4408 - val_accuracy: 0.7933
# Epoch 34/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4203 - accuracy: 0.7990 - val_loss: 0.4400 - val_accuracy: 0.7933
# Epoch 35/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.4195 - accuracy: 0.7990 - val_loss: 0.4393 - val_accuracy: 0.7933
# Epoch 36/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4187 - accuracy: 0.7990 - val_loss: 0.4387 - val_accuracy: 0.7936
# Epoch 37/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4180 - accuracy: 0.8076 - val_loss: 0.4382 - val_accuracy: 0.8065
# Epoch 38/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4174 - accuracy: 0.8108 - val_loss: 0.4374 - val_accuracy: 0.8073
# Epoch 39/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.4167 - accuracy: 0.8117 - val_loss: 0.4369 - val_accuracy: 0.8080
# Epoch 40/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.4160 - accuracy: 0.8132 - val_loss: 0.4363 - val_accuracy: 0.8080
# Epoch 41/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.4154 - accuracy: 0.8141 - val_loss: 0.4360 - val_accuracy: 0.8099
# Epoch 42/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4148 - accuracy: 0.8141 - val_loss: 0.4350 - val_accuracy: 0.8095
# Epoch 43/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.4141 - accuracy: 0.8155 - val_loss: 0.4344 - val_accuracy: 0.8103
# Epoch 44/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.4134 - accuracy: 0.8166 - val_loss: 0.4338 - val_accuracy: 0.8122
# Epoch 45/100
# 536/536 [==============================] - 2s 5ms/step - loss: 0.4127 - accuracy: 0.8169 - val_loss: 0.4333 - val_accuracy: 0.8126
# Epoch 46/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.4121 - accuracy: 0.8186 - val_loss: 0.4327 - val_accuracy: 0.8122
# Epoch 47/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4115 - accuracy: 0.8188 - val_loss: 0.4322 - val_accuracy: 0.8129
# Epoch 48/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.4108 - accuracy: 0.8190 - val_loss: 0.4316 - val_accuracy: 0.8129
# Epoch 49/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4103 - accuracy: 0.8199 - val_loss: 0.4312 - val_accuracy: 0.8137
# Epoch 50/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4097 - accuracy: 0.8222 - val_loss: 0.4308 - val_accuracy: 0.8145
# Epoch 51/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4092 - accuracy: 0.8216 - val_loss: 0.4302 - val_accuracy: 0.8145
# Epoch 52/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4087 - accuracy: 0.8233 - val_loss: 0.4300 - val_accuracy: 0.8160
# Epoch 53/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4082 - accuracy: 0.8238 - val_loss: 0.4296 - val_accuracy: 0.8167
# Epoch 54/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4078 - accuracy: 0.8244 - val_loss: 0.4291 - val_accuracy: 0.8171
# Epoch 55/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4072 - accuracy: 0.8261 - val_loss: 0.4285 - val_accuracy: 0.8171
# Epoch 56/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4069 - accuracy: 0.8259 - val_loss: 0.4281 - val_accuracy: 0.8179
# Epoch 57/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4065 - accuracy: 0.8259 - val_loss: 0.4280 - val_accuracy: 0.8167
# Epoch 58/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4061 - accuracy: 0.8270 - val_loss: 0.4275 - val_accuracy: 0.8171
# Epoch 59/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4056 - accuracy: 0.8263 - val_loss: 0.4271 - val_accuracy: 0.8186
# Epoch 60/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4051 - accuracy: 0.8283 - val_loss: 0.4273 - val_accuracy: 0.8167
# Epoch 61/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4050 - accuracy: 0.8276 - val_loss: 0.4267 - val_accuracy: 0.8186
# Epoch 62/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4045 - accuracy: 0.8291 - val_loss: 0.4263 - val_accuracy: 0.8183
# Epoch 63/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4041 - accuracy: 0.8302 - val_loss: 0.4261 - val_accuracy: 0.8179
# Epoch 64/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4038 - accuracy: 0.8298 - val_loss: 0.4255 - val_accuracy: 0.8186
# Epoch 65/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4034 - accuracy: 0.8289 - val_loss: 0.4251 - val_accuracy: 0.8190
# Epoch 66/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4030 - accuracy: 0.8294 - val_loss: 0.4250 - val_accuracy: 0.8186
# Epoch 67/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4027 - accuracy: 0.8306 - val_loss: 0.4246 - val_accuracy: 0.8186
# Epoch 68/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4023 - accuracy: 0.8322 - val_loss: 0.4243 - val_accuracy: 0.8190
# Epoch 69/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4021 - accuracy: 0.8313 - val_loss: 0.4241 - val_accuracy: 0.8186
# Epoch 70/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.4017 - accuracy: 0.8315 - val_loss: 0.4240 - val_accuracy: 0.8190
# Epoch 71/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.4014 - accuracy: 0.8321 - val_loss: 0.4237 - val_accuracy: 0.8194
# Epoch 72/100
# 536/536 [==============================] - 2s 5ms/step - loss: 0.4012 - accuracy: 0.8313 - val_loss: 0.4237 - val_accuracy: 0.8194
# Epoch 73/100
# 536/536 [==============================] - 2s 5ms/step - loss: 0.4008 - accuracy: 0.8324 - val_loss: 0.4235 - val_accuracy: 0.8201
# Epoch 74/100
# 536/536 [==============================] - 2s 5ms/step - loss: 0.4004 - accuracy: 0.8321 - val_loss: 0.4233 - val_accuracy: 0.8213
# Epoch 75/100
# 536/536 [==============================] - 2s 5ms/step - loss: 0.4002 - accuracy: 0.8321 - val_loss: 0.4230 - val_accuracy: 0.8224
# Epoch 76/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3998 - accuracy: 0.8322 - val_loss: 0.4226 - val_accuracy: 0.8228
# Epoch 77/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3994 - accuracy: 0.8324 - val_loss: 0.4223 - val_accuracy: 0.8243
# Epoch 78/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3991 - accuracy: 0.8330 - val_loss: 0.4223 - val_accuracy: 0.8232
# Epoch 79/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3988 - accuracy: 0.8332 - val_loss: 0.4219 - val_accuracy: 0.8243
# Epoch 80/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3985 - accuracy: 0.8326 - val_loss: 0.4218 - val_accuracy: 0.8239
# Epoch 81/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3983 - accuracy: 0.8341 - val_loss: 0.4217 - val_accuracy: 0.8239
# Epoch 82/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3980 - accuracy: 0.8347 - val_loss: 0.4212 - val_accuracy: 0.8247
# Epoch 83/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3977 - accuracy: 0.8349 - val_loss: 0.4211 - val_accuracy: 0.8247
# Epoch 84/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3974 - accuracy: 0.8341 - val_loss: 0.4207 - val_accuracy: 0.8251
# Epoch 85/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3971 - accuracy: 0.8341 - val_loss: 0.4206 - val_accuracy: 0.8254
# Epoch 86/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3969 - accuracy: 0.8362 - val_loss: 0.4204 - val_accuracy: 0.8251
# Epoch 87/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3966 - accuracy: 0.8349 - val_loss: 0.4199 - val_accuracy: 0.8262
# Epoch 88/100
# 536/536 [==============================] - 3s 5ms/step - loss: 0.3962 - accuracy: 0.8360 - val_loss: 0.4198 - val_accuracy: 0.8262
# Epoch 89/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3959 - accuracy: 0.8358 - val_loss: 0.4196 - val_accuracy: 0.8273
# Epoch 90/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3955 - accuracy: 0.8364 - val_loss: 0.4193 - val_accuracy: 0.8281
# Epoch 91/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3953 - accuracy: 0.8358 - val_loss: 0.4189 - val_accuracy: 0.8273
# Epoch 92/100
# 536/536 [==============================] - 2s 4ms/step - loss: 0.3949 - accuracy: 0.8364 - val_loss: 0.4186 - val_accuracy: 0.8270
# Epoch 93/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3944 - accuracy: 0.8369 - val_loss: 0.4180 - val_accuracy: 0.8289
# Epoch 94/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3939 - accuracy: 0.8367 - val_loss: 0.4183 - val_accuracy: 0.8270
# Epoch 95/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3937 - accuracy: 0.8377 - val_loss: 0.4174 - val_accuracy: 0.8292
# Epoch 96/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3932 - accuracy: 0.8375 - val_loss: 0.4168 - val_accuracy: 0.8304
# Epoch 97/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3925 - accuracy: 0.8375 - val_loss: 0.4164 - val_accuracy: 0.8300
# Epoch 98/100
# 536/536 [==============================] - ETA: 0s - loss: 0.3909 - accuracy: 0.83 - 1s 1ms/step - loss: 0.3918 - accuracy: 0.8382 - val_loss: 0.4154 - val_accuracy: 0.8319
# Epoch 99/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3909 - accuracy: 0.8391 - val_loss: 0.4147 - val_accuracy: 0.8330
# Epoch 100/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3900 - accuracy: 0.8393 - val_loss: 0.4138 - val_accuracy: 0.8334

# %%
print(model_history.history.keys())


# summarize history for accuracy
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# summarize history for loss
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
cm
# Out:
# array([[1544,   42],
#        [ 279,  135]], dtype=int64)

# %%
# Calculate the Accuracy
from sklearn.metrics import accuracy_score
score=accuracy_score(y_pred,y_test)

# %%
score
# Out:
# 0.8395

# %%
# u can also use droput to avoid overfitting
